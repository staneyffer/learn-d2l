# %% [markdown]
# ## 长短期记忆网络(Long Short-Term Memory)
#
# - 忘记门：将值朝0减少
# - 输入门：决定是不是忽略掉输入数据
# - 输出门：决定是不是使用隐状态
#
# 效果跟GRU类似，不过比GRU复杂

# %% [markdown]
# ![image.png](attachment:1241b4be-2975-40a9-ada8-ecea6610fdac.png)

# %% [markdown]
# ## 候选记忆单元
# ![image.png](attachment:b0cada99-d613-4def-9f5e-65ca9228d4bb.png)

# %% [markdown]
# ## 记忆单元
#
# ![image.png](attachment:82fadc8b-ee10-48c8-a013-b753aca468b4.png)

# %% [markdown]
# ## 隐状态
#
# ![image.png](attachment:e9fcb611-55ef-4808-876f-4e069d792b96.png)

# %% [markdown]
# ## 总结
#
# ![image.png](attachment:f5c02e47-d37d-4c7a-aedd-b71a20b878c8.png)
#
# ![image.png](attachment:93e6ddf2-de27-4663-a41c-dd8a8bbc2695.png)
