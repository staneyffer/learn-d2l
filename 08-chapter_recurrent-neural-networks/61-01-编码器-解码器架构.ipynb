# %% [markdown]
# ## 编码器-解码器架构
#
# ## 重新考察CNN
#
# ![image.png](attachment:aaa004c4-f132-43f6-8d9c-fe7f1d566060.png)
#
# - 编码器： 将输入编程成中间表达形式（特征）
# - 解码器：建哥中间表示解码成输出

# %% [markdown]
# ## 重新考察RNN
#
# ![image.png](attachment:f6163ee3-7a9c-46e1-86c7-0e40596f0873.png)

# %% [markdown]
# ## 编码器-解码器架构
#
# - 一个模型被分为两块
#     - 编码器处理输入
#     - 解码器生成输出
#
# ![image.png](attachment:6a128f27-b832-452e-81e4-3afc8f93699d.png)

# %% [markdown]
# ## 总结
# - 使用编码器-解码器架构的模型，编码器负责表示输入，解码器负责输出
