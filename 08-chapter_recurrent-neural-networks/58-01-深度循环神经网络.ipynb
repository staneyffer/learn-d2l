# %% [markdown]
# ## 深度循环神经网络

# %% [markdown]
# ## 更深
#
# ![image.png](attachment:f62f1ab1-267c-47e5-afd9-5404a53f9400.png)
#
#
# ![image.png](attachment:69fcf7de-abc7-4603-87f7-80ca58de92d7.png)

# %% [markdown]
# ## 总结
#
# - 深度循环神经网络使用多个隐藏层来获得更多的非线性性
