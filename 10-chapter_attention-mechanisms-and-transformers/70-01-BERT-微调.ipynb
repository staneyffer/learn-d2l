# %% [markdown]
# ## 微调BERT
#
# - BERT对每一个词元返回抽取了上下文信息的特征向量
# - 不同的任务使用不同的特征
#
# ![image.png](attachment:97f44ced-3de1-4b42-a423-0e872ba1c584.png)

# %% [markdown]
# ## 句子分类
#
# - 将\<cls\> 对应的向量输入到全连接层分类
#
# ![image.png](attachment:f4693dd1-cb96-4bf0-abf4-54aba4ac5f73.png)

# %% [markdown]
# ## 命名实体识别(NER)
# - 识别一个词元是不是命名实体，例如人名、机构、位置
# - 讲非特殊词放进全连接层
#
# ![image.png](attachment:fc97e631-5863-43fa-96ef-81429c6b3ebe.png)

# %% [markdown]
# ## 问题回答
#
# - 给定一个问题，和描述文字，找出一个片段作为回答
# - 对片段中的每个词元预测它是不是回答的开头或结束
#
# ![image.png](attachment:cb8ad348-80b1-4e9e-8948-3ec67bd5a639.png)

# %% [markdown]
# ## 总结
#
# - 即使下游任务各有不同，使用BERT微调时均只需要增加输出层
# - 但根据任务的不同，输入的表示，和使用的BERT特征也会不一样
