# %% [markdown]
# ## 自注意力和位置编码
#
# ![image.png](attachment:a6ecfc63-fc72-4c99-a60e-b9bf19509af7.png)
#
# ![image.png](attachment:867fde01-adef-4bd6-bea4-bef05f352cc6.png)

# %% [markdown]
# ## 跟CNN，RNN对比
#
# ![image.png](attachment:75a15cd7-794a-4e19-ac94-dcb51d70741d.png)
#
# ![image.png](attachment:c2cc72d3-2b47-4ffb-af71-4a563bb3f323.png)
