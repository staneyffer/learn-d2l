# %% [markdown]
# ## 使用了注意力机制的Seq2seq
#
# ## 动机
#
# - 机器翻译中，每个生成的词可能相关于源句子中不同的词
# 本质上是句子与句子只有有位置的对应关系，我们希望翻译过程中，给对应位置的词更高的权重
#
# ![image.png](attachment:7291cf5d-a088-4a7a-8a79-ac5b69d48716.png)
#
# - seq2seq模型中不能对此直接建模

# %% [markdown]
# ## 加入注意力
#
# ![image.png](attachment:7ce8dcb8-eee4-469d-afaf-63948ba73054.png)
#
# - 编码器对每次词的输出作为key和value
# - 解码器RNN对上一个词的预测输出是query
# - 注意力的输出和下一个词的词嵌入合并进入RNN

# %% [markdown]
# ## 总结
#
# - Seq2seq中通过隐状态在编码器和解码器中传递信息
# - 注意力机制可以根据解码器RNN的输出来匹配到合适的编码器RNN的输出来更有效地传递信息
