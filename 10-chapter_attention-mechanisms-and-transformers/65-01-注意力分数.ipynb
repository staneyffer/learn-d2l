# %% [markdown]
# ## 注意力分数函数(Attention Scoring Functions)
#
# ![image.png](attachment:1ba241b9-0570-443d-916d-a1c8f0bf732e.png)
#
# ![image.png](attachment:3775d022-31df-4ac8-8cb8-d56726863c80.png)

# %% [markdown]
# ## 扩展到高纬度
#
# ![image.png](attachment:86e9d152-d862-4773-a62c-64d40f6f6c8c.png)
#
# ![image.png](attachment:7954d8a7-9b52-4378-971c-6f79b4683a6d.png)

# %% [markdown]
# ## Additive Attention
#
# ![image.png](attachment:c9614f3c-5953-4f1a-81da-a5fd7da265a5.png)
#
# - 等价于将query和key合并起来后放入到一个隐藏大小为h输出大小为1的单隐藏层MLP

# %% [markdown]
# ## Scaled Dot-Product Attention
#
# ![image.png](attachment:6854ca33-a4c5-43ec-9f00-419e6ebce302.png)
#
# ![image.png](attachment:c03678a1-465f-4f96-8533-536f8eff109f.png)

# %% [markdown]
# ## 总结
#
# - 注意力分数是query和key的相似度，注意力权重是分数的softmax结果
# - 两种常见的分数计算：
#     - 将query和key合并起来进入一个单输出隐藏层的MLP
#     - 直接将query和key做内积
