# %% [markdown]
# ## 残差网络（ResNet）
# ### 加更多的层总是改进精度吗？
#
# ![image.png](attachment:f250eeb2-aa3e-4f41-bccd-dc66cd89268f.png)
#
# ResNet做的事情：加更多的层，虽然不一定更好，但是一定不会变得更差，通常是变得更好

# %% [markdown]
# ## 残差块
#
# - 串联一个层改变函数类，我们希望能扩大函数类
# - 残差块加入快速通道来得到 $f(x) = x + g(x)$的结构
#
# ![image.png](attachment:67b61779-f3df-4632-8d8e-6eb5925c5525.png)
#
# ## 细节
#
# ![image.png](attachment:fece087d-2f48-425b-8bf2-3eb1df0870e8.png)

# %% [markdown]
# ## 不同版本的残差块
#
# ![image.png](attachment:a1ba50e8-b566-4fd5-9278-3492d39b4e40.png)
#
#
# ## ResNet块
#
# ![image.png](attachment:99378378-b4b3-4856-8edf-b811cd4dbc6e.png)

# %% [markdown]
# ## ResNet架构
#
# ![image.png](attachment:68366769-e3af-4b1c-aa26-cb59baf7a086.png)

# %% [markdown]
# ## 总结
#
# - 残差块使得很深的网络更加容易训练
#     - 甚至可以训练一千层的网络
# - 残差网络对随后的深层神经网络设计产生了深远影响，无论是卷积类网络还是全连接类网络
